# %%
# Import the libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import IFrame
import folium
from folium.plugins import MarkerCluster
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import mean_squared_error,  r2_score
from sklearn.preprocessing import StandardScaler 
from sklearn.tree import DecisionTreeRegressor

# %%
#import the dataset
df = pd.read_csv('/Users/uzma/desktop/motor_crash_collision_data.csv')
display(df.tail(20))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 2051560  12/08/2023      13:40   BROOKLYN  11215.0  40.672665 -73.988280
# 2051561  12/09/2023      22:10        NaN      NaN        NaN        NaN
# 2051562  12/16/2023      22:03     QUEENS  11427.0  40.726227 -73.756714
# 2051563  12/16/2023      12:21     QUEENS  11432.0  40.717800 -73.803580
# 2051564  12/09/2023      22:20  MANHATTAN  10016.0  40.740530 -73.975900
# 2051565  12/16/2023       6:20     QUEENS  11354.0  40.763940 -73.828156
# 2051566  12/16/2023      17:04   BROOKLYN  11226.0  40.646923 -73.948180
# 2051567  12/16/2023       5:55        NaN      NaN  40.703780 -73.816210
# 2051568  12/16/2023      11:50  MANHATTAN  10035.0  40.798275 -73.933740
# 2051569  12/15/2023      15:50  MANHATTAN  10032.0  40.831960 -73.943900
# 2051570  12/16/2023      15:16   BROOKLYN  11211.0  40.714996 -73.959480
# 2051571  12/16/2023      23:00      BRONX  10467.0  40.872210 -73.877130
# 2051572  12/05/2023      13:00   BROOKLYN  11234.0  40.634130 -73.928505
# 2051573  12/15/2023      12:28     QUEENS  11377.0  40.753708 -73.902990
# 2051574  12/16/2023      18:00     QUEENS  11373.0  40.737076 -73.874950
# 2051575  12/16/2023       6:30   BROOKLYN  11236.0  40.654526 -73.899086
# 2051576  12/15/2023      11:30  MANHATTAN  10004.0  40.706238 -74.014340
# 2051577  12/08/2023      17:15        NaN      NaN  40.790210 -73.975030
# 2051578  12/15/2023      16:25      BRONX  10454.0  40.804634 -73.922280
# 2051579  12/16/2023      13:34     QUEENS  11413.0  40.675274 -73.753600
#
#                         LOCATION         ON STREET NAME     CROSS STREET NAME  \
# 2051560   (40.672665, -73.98828)                    NaN                   NaN
# 2051561                      NaN      TRIBOROUGH BRIDGE                   NaN
# 2051562  (40.726227, -73.756714)  GRAND CENTRAL PARKWAY  CLEARVIEW EXPRESSWAY
# 2051563     (40.7178, -73.80358)                82 ROAD            164 STREET
# 2051564     (40.74053, -73.9759)                    NaN                   NaN
# 2051565   (40.76394, -73.828156)     NORTHERN BOULEVARD          UNION STREET
# 2051566   (40.646923, -73.94818)          TILDEN AVENUE        EAST 31 STREET
# 2051567    (40.70378, -73.81621)     VANWYCK EXPRESSWAY            138 STREET
# 2051568   (40.798275, -73.93374)                    NaN                   NaN
# 2051569     (40.83196, -73.9439)                    NaN                   NaN
# 2051570   (40.714996, -73.95948)         NORTH 3 STREET   METROPOLITAN AVENUE
# 2051571    (40.87221, -73.87713)                    NaN                   NaN
# 2051572   (40.63413, -73.928505)          KINGS HIGHWAY          UTICA AVENUE
# 2051573   (40.753708, -73.90299)              58 STREET    NORTHERN BOULEVARD
# 2051574   (40.737076, -73.87495)                    NaN                   NaN
# 2051575  (40.654526, -73.899086)                    NaN                   NaN
# 2051576   (40.706238, -74.01434)          MORRIS STREET      GREENWICH STREET
# 2051577    (40.79021, -73.97503)               BROADWAY                   NaN
# 2051578   (40.804634, -73.92228)                    NaN                   NaN
# 2051579    (40.675274, -73.7536)                    NaN                   NaN
#
#                       OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 2051560            242       6 STREET  ...                    Unspecified
# 2051561                           NaN  ...                    Unspecified
# 2051562                           NaN  ...                    Unspecified
# 2051563                           NaN  ...                    Unspecified
# 2051564            491       1 AVENUE  ...   Aggressive Driving/Road Rage
# 2051565                           NaN  ...                    Unspecified
# 2051566                           NaN  ...                    Unspecified
# 2051567                           NaN  ...                            NaN
# 2051568            2330      1 AVENUE  ...                    Unspecified
# 2051569     525       WEST 155 STREET  ...                    Unspecified
# 2051570                           NaN  ...                    Unspecified
# 2051571      3129      DECATUR AVENUE  ...                    Unspecified
# 2051572                           NaN  ...                    Unspecified
# 2051573                           NaN  ...                    Unspecified
# 2051574           88-15     54 AVENUE  ...                            NaN
# 2051575         807       BANK STREET  ...          Following Too Closely
# 2051576                           NaN  ...                    Unspecified
# 2051577                           NaN  ...                    Unspecified
# 2051578  114       BRUCKNER BOULEVARD  ...                    Unspecified
# 2051579            217-06    137 ROAD  ...                            NaN
#
#          CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 2051560                            NaN                            NaN
# 2051561                            NaN                            NaN
# 2051562                            NaN                            NaN
# 2051563                            NaN                            NaN
# 2051564                    Unspecified                            NaN
# 2051565                            NaN                            NaN
# 2051566                            NaN                            NaN
# 2051567                            NaN                            NaN
# 2051568                            NaN                            NaN
# 2051569                            NaN                            NaN
# 2051570                    Unspecified                            NaN
# 2051571                            NaN                            NaN
# 2051572                            NaN                            NaN
# 2051573                            NaN                            NaN
# 2051574                            NaN                            NaN
# 2051575                            NaN                            NaN
# 2051576                            NaN                            NaN
# 2051577                            NaN                            NaN
# 2051578                            NaN                            NaN
# 2051579                            NaN                            NaN
#
#          CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 2051560                            NaN       4688332
# 2051561                            NaN       4688093
# 2051562                            NaN       4687670
# 2051563                            NaN       4687598
# 2051564                            NaN       4688132
# 2051565                            NaN       4688184
# 2051566                            NaN       4687761
# 2051567                            NaN       4687731
# 2051568                            NaN       4688151
# 2051569                            NaN       4688320
# 2051570                            NaN       4687881
# 2051571                            NaN       4688007
# 2051572                            NaN       4688282
# 2051573                            NaN       4688239
# 2051574                            NaN       4688076
# 2051575                            NaN       4687853
# 2051576                            NaN       4688212
# 2051577                            NaN       4688225
# 2051578                            NaN       4688254
# 2051579                            NaN       4687943
#
#                          VEHICLE TYPE CODE 1  \
# 2051560  Station Wagon/Sport Utility Vehicle
# 2051561                                   l1
# 2051562  Station Wagon/Sport Utility Vehicle
# 2051563                                Sedan
# 2051564                                Sedan
# 2051565  Station Wagon/Sport Utility Vehicle
# 2051566                                Sedan
# 2051567                                Sedan
# 2051568                                Sedan
# 2051569                                Sedan
# 2051570                                Sedan
# 2051571                                Sedan
# 2051572  Station Wagon/Sport Utility Vehicle
# 2051573  Station Wagon/Sport Utility Vehicle
# 2051574  Station Wagon/Sport Utility Vehicle
# 2051575                        Pick-up Truck
# 2051576  Station Wagon/Sport Utility Vehicle
# 2051577  Station Wagon/Sport Utility Vehicle
# 2051578                                Sedan
# 2051579                                Sedan
#
#                          VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3  \
# 2051560                            Box Truck                  NaN
# 2051561                                Sedan                  NaN
# 2051562                                Sedan                  NaN
# 2051563                            E-Scooter                  NaN
# 2051564                                Sedan                Sedan
# 2051565  Station Wagon/Sport Utility Vehicle                  NaN
# 2051566  Station Wagon/Sport Utility Vehicle                  NaN
# 2051567                                  NaN                  NaN
# 2051568                                Sedan                  NaN
# 2051569                                Sedan                  NaN
# 2051570                                Sedan                Sedan
# 2051571                                  NaN                  NaN
# 2051572                                  Bus                  NaN
# 2051573                                Sedan                  NaN
# 2051574                                  NaN                  NaN
# 2051575                                Sedan                  NaN
# 2051576                                 Dump                  NaN
# 2051577                            Box Truck                  NaN
# 2051578                                Sedan                  NaN
# 2051579                                  NaN                  NaN
#
#         VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 2051560                 NaN                 NaN
# 2051561                 NaN                 NaN
# 2051562                 NaN                 NaN
# 2051563                 NaN                 NaN
# 2051564                 NaN                 NaN
# 2051565                 NaN                 NaN
# 2051566                 NaN                 NaN
# 2051567                 NaN                 NaN
# 2051568                 NaN                 NaN
# 2051569                 NaN                 NaN
# 2051570                 NaN                 NaN
# 2051571                 NaN                 NaN
# 2051572                 NaN                 NaN
# 2051573                 NaN                 NaN
# 2051574                 NaN                 NaN
# 2051575                 NaN                 NaN
# 2051576                 NaN                 NaN
# 2051577                 NaN                 NaN
# 2051578                 NaN                 NaN
# 2051579                 NaN                 NaN
#
# [20 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# CRASH DATE                             0
# CRASH TIME                             0
# BOROUGH                           638220
# ZIP CODE                          638468
# LATITUDE                          232153
# LONGITUDE                         232153
# LOCATION                          232153
# ON STREET NAME                    433962
# CROSS STREET NAME                 772282
# OFF STREET NAME                  1709991
# NUMBER OF PERSONS INJURED             18
# NUMBER OF PERSONS KILLED              31
# NUMBER OF PEDESTRIANS INJURED          0
# NUMBER OF PEDESTRIANS KILLED           0
# NUMBER OF CYCLIST INJURED              0
# NUMBER OF CYCLIST KILLED               0
# NUMBER OF MOTORIST INJURED             0
# NUMBER OF MOTORIST KILLED              0
# CONTRIBUTING FACTOR VEHICLE 1       6609
# CONTRIBUTING FACTOR VEHICLE 2     315769
# CONTRIBUTING FACTOR VEHICLE 3    1905498
# CONTRIBUTING FACTOR VEHICLE 4    2018716
# CONTRIBUTING FACTOR VEHICLE 5    2042686
# COLLISION_ID                           0
# VEHICLE TYPE CODE 1                13259
# VEHICLE TYPE CODE 2               388198
# VEHICLE TYPE CODE 3              1910721
# VEHICLE TYPE CODE 4              2019835
# VEHICLE TYPE CODE 5              2042955
# dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %%
df.columns = df.columns.str.replace(" ", "_")
df.columns
# Out:
# Index(['CRASH_DATE', 'CRASH_TIME', 'BOROUGH', 'ZIP_CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON_STREET_NAME', 'CROSS_STREET_NAME',
#        'OFF_STREET_NAME', 'NUMBER_OF_PERSONS_INJURED',
#        'NUMBER_OF_PERSONS_KILLED', 'NUMBER_OF_PEDESTRIANS_INJURED',
#        'NUMBER_OF_PEDESTRIANS_KILLED', 'NUMBER_OF_CYCLIST_INJURED',
#        'NUMBER_OF_CYCLIST_KILLED', 'NUMBER_OF_MOTORIST_INJURED',
#        'NUMBER_OF_MOTORIST_KILLED', 'CONTRIBUTING_FACTOR_VEHICLE_1',
#        'CONTRIBUTING_FACTOR_VEHICLE_2', 'CONTRIBUTING_FACTOR_VEHICLE_3',
#        'CONTRIBUTING_FACTOR_VEHICLE_4', 'CONTRIBUTING_FACTOR_VEHICLE_5',
#        'COLLISION_ID', 'VEHICLE_TYPE_CODE_1', 'VEHICLE_TYPE_CODE_2',
#        'VEHICLE_TYPE_CODE_3', 'VEHICLE_TYPE_CODE_4', 'VEHICLE_TYPE_CODE_5'],
#       dtype='object')

# %% [markdown]
# ## Check for missing value

# %%
df.isnull().sum()
# Out:
# CRASH_DATE                             0
# CRASH_TIME                             0
# BOROUGH                           638220
# ZIP_CODE                          638468
# LATITUDE                          232153
# LONGITUDE                         232153
# LOCATION                          232153
# ON_STREET_NAME                    433962
# CROSS_STREET_NAME                 772282
# OFF_STREET_NAME                  1709991
# NUMBER_OF_PERSONS_INJURED             18
# NUMBER_OF_PERSONS_KILLED              31
# NUMBER_OF_PEDESTRIANS_INJURED          0
# NUMBER_OF_PEDESTRIANS_KILLED           0
# NUMBER_OF_CYCLIST_INJURED              0
# NUMBER_OF_CYCLIST_KILLED               0
# NUMBER_OF_MOTORIST_INJURED             0
# NUMBER_OF_MOTORIST_KILLED              0
# CONTRIBUTING_FACTOR_VEHICLE_1       6609
# CONTRIBUTING_FACTOR_VEHICLE_2     315769
# CONTRIBUTING_FACTOR_VEHICLE_3    1905498
# CONTRIBUTING_FACTOR_VEHICLE_4    2018716
# CONTRIBUTING_FACTOR_VEHICLE_5    2042686
# COLLISION_ID                           0
# VEHICLE_TYPE_CODE_1                13259
# VEHICLE_TYPE_CODE_2               388198
# VEHICLE_TYPE_CODE_3              1910721
# VEHICLE_TYPE_CODE_4              2019835
# VEHICLE_TYPE_CODE_5              2042955
# dtype: int64

# %% [markdown]
# ##  Group by Borough and suming total killed and injured

# %%
Borough_group = df.groupby('BOROUGH').agg({'NUMBER_OF_PERSONS_KILLED': 'sum', 'NUMBER_OF_PERSONS_INJURED': 'sum'})


fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10), sharex=True)

ax1.bar(Borough_group.index, Borough_group['NUMBER_OF_PERSONS_KILLED'], color='red', label='Persons Killed')
ax1.set_ylabel('Number of Persons Killed')
ax1.legend()

ax2.bar(Borough_group.index, Borough_group['NUMBER_OF_PERSONS_INJURED'], color='orange', label='Persons Injured')
ax2.set_ylabel('Number of Persons Injured')
ax2.legend()

plt.xlabel('Borough')
plt.suptitle('Total Persons Killed and Injured by Borough', y=0.95)
plt.show()

# %%
Injured_pcts = Borough_group.NUMBER_OF_PERSONS_INJURED/Borough_group.NUMBER_OF_PERSONS_INJURED.sum()
print("Injured % by borough")
Injured_pcts
# Out:
# Injured % by borough
# BOROUGH
# BRONX            0.164748
# BROOKLYN         0.358618
# MANHATTAN        0.160993
# QUEENS           0.274795
# STATEN ISLAND    0.040846
# Name: NUMBER_OF_PERSONS_INJURED, dtype: float64

# %%
killd_pcts = Borough_group.NUMBER_OF_PERSONS_KILLED/Borough_group.NUMBER_OF_PERSONS_KILLED.sum()
print("Killed % by borough")
killd_pcts
# Out:
# Killed % by borough
# BOROUGH
# BRONX            0.146341
# BROOKLYN         0.335920
# MANHATTAN        0.180155
# QUEENS           0.286585
# STATEN ISLAND    0.050998
# Name: NUMBER_OF_PERSONS_KILLED, dtype: float64

# %% [markdown]
# ## Group by month summing total killed and injured

# %%
df['CRASH_DATE'] = pd.to_datetime(df['CRASH_DATE'])
group_month = df.groupby(df['CRASH_DATE'].dt.month).agg({
    'NUMBER_OF_PERSONS_KILLED': 'sum',
    'NUMBER_OF_PERSONS_INJURED': 'sum'
})

# Changing the name of the month number to month name
month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
group_month.index = month

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10), sharex=True)

# Bar plot for persons killed
ax1.bar(group_month.index, group_month['NUMBER_OF_PERSONS_KILLED'], color='red', label='Persons Killed')
ax1.set_ylabel('Number of Persons Killed')
ax1.legend()

# Bar plot for persons injured
ax2.bar(group_month.index, group_month['NUMBER_OF_PERSONS_INJURED'], color='orange', label='Persons Injured')
ax2.set_ylabel('Number of Persons Injured')
ax2.legend()

plt.xlabel('Month')
plt.suptitle('Total Persons Killed and Injured by Month', y=0.95)
plt.show()
